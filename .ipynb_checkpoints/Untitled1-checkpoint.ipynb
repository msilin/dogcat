# %%
import pandas as pd
import ast
import json
import requests
import xmltodict
from pandas.io.json import json_normalize #package for flattening json in pandas df


pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', 40)


df2 = pd.DataFrame()


itemz = []

with open('app.log') as f:
   items = f.read().split("**********************************************")[1:]
   
   for s in items:
          item = {}
          lines = s.splitlines()
          if ("Forwarded:" in s):
              item['path'] = lines[1]
              item['time'] = lines[3].lstrip('time: ')
              item['Referer'] = lines[5].lstrip('Referer: ')
              item['User-Agent'] = lines[6].lstrip('User-Agent: ')
              item['Connection'] = lines[7].lstrip('Connection: ')
              item['cookie'] = lines[2].lstrip("MMM COOKIE ").rstrip("@@@")
              item['Host'] = lines[9].lstrip('Host: ' )
              item['Upgrade-Insecure-Requests'] = lines[10].strip('Upgrade-Insecure-Requests: ')
              item['Accept']          = lines[11].lstrip('Accept: ')
              item['Accept-Language'] = lines[12].lstrip('Accept-Language: ')
              item['Accept-Encoding'] = lines[13].lstrip('Accept-Encoding: ')
              url = "https://freegeoip.app/xml/"
              ip = lines[8].lstrip('Forwarded: for="').rstrip('"')
              response = requests.get(url+ip)
              response = xmltodict.parse(response.text)['Response']
              item['IP'] = ip
              item['CountryCode'] = response['CountryCode']
              item['RegionCode'] = response['RegionCode']
              item['City'] = response['City']
              item['ZipCode'] = response['ZipCode']
              itemz.append(item)

df = pd.DataFrame(itemz)
df.to_csv('DF.csv', header=False, index=False)

# %%
import pandas as pd

df3 = pd.read_csv("DF2.csv")
df3
# Out:
#      -Language: sw  Unnamed: 1  Encoding: gzip        Busan  keep-alive  KR  \
# 0    -Language: sw         NaN  Encoding: gzip        Busan  keep-alive  KR
# 1    -Language: sw         NaN  Encoding: gzip        Busan  keep-alive  KR
# 2    -Language: sw         NaN  Encoding: gzip        Busan  keep-alive  KR
# 3    -Language: sw         NaN  Encoding: gzip        Busan  keep-alive  KR
# 4    -Language: sw         NaN  Encoding: gzip        Busan  keep-alive  KR
# 5    -Language: sw         NaN  Encoding: gzip        Busan  keep-alive  KR
# 6    -Language: oj         NaN  Encoding: gzip          NaN  keep-alive  US
# 7    -Language: oj         NaN  Encoding: gzip          NaN  keep-alive  US
# 8    -Language: oj         NaN  Encoding: gzip          NaN  keep-alive  US
# 9    -Language: oj         NaN  Encoding: gzip          NaN  keep-alive  US
# 10   -Language: oj         NaN  Encoding: gzip          NaN  keep-alive  US
# 11   -Language: oj         NaN  Encoding: gzip          NaN  keep-alive  US
# 12   -Language: oj         NaN  Encoding: gzip          NaN  keep-alive  US
# 13   -Language: oj         NaN  Encoding: gzip          NaN  keep-alive  US
# 14   -Language: oj         NaN  Encoding: gzip          NaN  keep-alive  US
# 15   -Language: ts         NaN  Encoding: gzip  Forest Hill  keep-alive  US
# 16   -Language: ts         NaN  Encoding: gzip  Forest Hill  keep-alive  US
# 17   -Language: ts         NaN  Encoding: gzip  Forest Hill  keep-alive  US
# 18   -Language: ts         NaN  Encoding: gzip  Forest Hill  keep-alive  US
# 19   -Language: ts         NaN  Encoding: gzip  Forest Hill  keep-alive  US
# 20   -Language: ts         NaN  Encoding: gzip  Forest Hill  keep-alive  US
# 21   -Language: fr         NaN  Encoding: gzip          NaN  keep-alive  US
# 22   -Language: fr         NaN  Encoding: gzip          NaN  keep-alive  US
# 23   -Language: fr         NaN  Encoding: gzip          NaN  keep-alive  US
# 24   -Language: fr         NaN  Encoding: gzip          NaN  keep-alive  US
# 25   -Language: fr         NaN  Encoding: gzip          NaN  keep-alive  US
# 26   -Language: fr         NaN  Encoding: gzip          NaN  keep-alive  US
# 27   -Language: ng         NaN  Encoding: gzip      Beijing  keep-alive  CN
# 28   -Language: ng         NaN  Encoding: gzip      Beijing  keep-alive  CN
# 29   -Language: ng         NaN  Encoding: gzip      Beijing  keep-alive  CN
# ..             ...         ...             ...          ...         ...  ..
# 964  -Language: lu         NaN  Encoding: gzip          NaN  keep-alive  CN
# 965  -Language: lu         NaN  Encoding: gzip          NaN  keep-alive  CN
# 966  -Language: lu         NaN  Encoding: gzip          NaN  keep-alive  CN
# 967  -Language: lu         NaN  Encoding: gzip          NaN  keep-alive  CN
# 968  -Language: lu         NaN  Encoding: gzip          NaN  keep-alive  CN
# 969  -Language: lu         NaN  Encoding: gzip          NaN  keep-alive  CN
# 970  -Language: os         NaN  Encoding: gzip          NaN  keep-alive  US
# 971  -Language: os         NaN  Encoding: gzip          NaN  keep-alive  US
# 972  -Language: os         NaN  Encoding: gzip          NaN  keep-alive  US
# 973  -Language: os         NaN  Encoding: gzip          NaN  keep-alive  US
# 974  -Language: os         NaN  Encoding: gzip          NaN  keep-alive  US
# 975  -Language: ne         NaN  Encoding: gzip          NaN  keep-alive  US
# 976  -Language: ne         NaN  Encoding: gzip          NaN  keep-alive  US
# 977  -Language: ne         NaN  Encoding: gzip          NaN  keep-alive  US
# 978  -Language: ne         NaN  Encoding: gzip          NaN  keep-alive  US
# 979  -Language: ne         NaN  Encoding: gzip          NaN  keep-alive  US
# 980  -Language: ne         NaN  Encoding: gzip          NaN  keep-alive  US
# 981  -Language: ne         NaN  Encoding: gzip          NaN  keep-alive  US
# 982  -Language: ne         NaN  Encoding: gzip          NaN  keep-alive  US
# 983  -Language: ne         NaN  Encoding: gzip          NaN  keep-alive  US
# 984  -Language: ig         NaN  Encoding: gzip          NaN  keep-alive  US
# 985  -Language: ig         NaN  Encoding: gzip          NaN  keep-alive  US
# 986  -Language: ig         NaN  Encoding: gzip          NaN  keep-alive  US
# 987  -Language: ig         NaN  Encoding: gzip          NaN  keep-alive  US
# 988  -Language: ig         NaN  Encoding: gzip          NaN  keep-alive  US
# 989  -Language: ky         NaN  Encoding: gzip          NaN  keep-alive  JP
# 990  -Language: ky         NaN  Encoding: gzip          NaN  keep-alive  JP
# 991  -Language: ky         NaN  Encoding: gzip          NaN  keep-alive  JP
# 992  -Language: ky         NaN  Encoding: gzip          NaN  keep-alive  JP
# 993  -Language: ky         NaN  Encoding: gzip          NaN  keep-alive  JP
#
#      10.144.203.136  222.239.168.135  Unnamed: 8   26  Accept: */*  \
# 0    10.144.203.136  222.239.168.135         NaN   26  Accept: */*
# 1    10.144.203.136  222.239.168.135         NaN   26  Accept: */*
# 2    10.144.203.136  222.239.168.135         NaN   26  Accept: */*
# 3    10.144.203.136  222.239.168.135         NaN   26  Accept: */*
# 4    10.144.203.136  222.239.168.135         NaN   26  Accept: */*
# 5    10.144.203.136  222.239.168.135         NaN   26  Accept: */*
# 6    10.144.203.136    23.90.192.153         NaN  NaN  Accept: */*
# 7    10.144.203.136    23.90.192.153         NaN  NaN  Accept: */*
# 8    10.144.203.136    23.90.192.153         NaN  NaN  Accept: */*
# 9    10.144.203.136    23.90.192.153         NaN  NaN  Accept: */*
# 10   10.144.203.136    23.90.192.153         NaN  NaN  Accept: */*
# 11   10.144.203.136    23.90.192.153         NaN  NaN  Accept: */*
# 12   10.144.203.136    23.90.192.153         NaN  NaN  Accept: */*
# 13   10.144.203.136    23.90.192.153         NaN  NaN  Accept: */*
# 14   10.144.203.136    23.90.192.153         NaN  NaN  Accept: */*
# 15   10.144.203.136    24.112.128.30         NaN   MD  Accept: */*
# 16   10.144.203.136    24.112.128.30         NaN   MD  Accept: */*
# 17   10.144.203.136    24.112.128.30         NaN   MD  Accept: */*
# 18   10.144.203.136    24.112.128.30         NaN   MD  Accept: */*
# 19   10.144.203.136    24.112.128.30         NaN   MD  Accept: */*
# 20   10.144.203.136    24.112.128.30         NaN   MD  Accept: */*
# 21   10.144.203.136   130.45.245.242         NaN  NaN  Accept: */*
# 22   10.144.203.136   130.45.245.242         NaN  NaN  Accept: */*
NaN  02/14/2020, 22:57:00    /img/puppy1   02/14/2020, 22:57:00
# 968    NaN  02/14/2020, 22:57:00   /img/kitten2   02/14/2020, 22:57:00
# 969    NaN  02/14/2020, 22:57:00   /img/kitten2   02/14/2020, 22:57:00
# 970    NaN  02/14/2020, 22:57:00    /img/puppy3   02/14/2020, 22:57:00
# 971    NaN  02/14/2020, 22:57:00    /img/puppy3   02/14/2020, 22:57:00
# 972    NaN  02/14/2020, 22:57:00    /img/puppy3   02/14/2020, 22:57:00
# 973    NaN  02/14/2020, 22:57:00    /img/puppy3   02/14/2020, 22:57:00
# 974    NaN  02/14/2020, 22:57:00    /img/puppy1   02/14/2020, 22:57:00
# 975    NaN  02/14/2020, 22:57:00    /img/puppy2   02/14/2020, 22:57:00
# 976    NaN  02/14/2020, 22:57:00    /img/puppy1   02/14/2020, 22:57:00
# 977    NaN  02/14/2020, 22:57:00    /img/puppy3   02/14/2020, 22:57:00
# 978    NaN  02/14/2020, 22:57:00    /img/puppy3   02/14/2020, 22:57:00
# 979    NaN  02/14/2020, 22:57:00    /img/puppy1   02/14/2020, 22:57:00
# 980    NaN  02/14/2020, 22:57:00    /img/puppy1   02/14/2020, 22:57:00
# 981    NaN  02/14/2020, 22:57:00    /img/puppy1   02/14/2020, 22:57:00
# 982    NaN  02/14/2020, 22:57:00    /img/puppy1   02/14/2020, 22:57:00
# 983    NaN  02/14/2020, 22:57:01    /img/puppy3   02/14/2020, 22:57:01
# 984    NaN  02/14/2020, 22:57:01   /img/kitten3   02/14/2020, 22:57:01
# 985    NaN  02/14/2020, 22:57:01   /img/kitten3   02/14/2020, 22:57:01
# 986    NaN  02/14/2020, 22:57:01   /img/kitten2   02/14/2020, 22:57:01
# 987    NaN  02/14/2020, 22:57:01   /img/kitten2   02/14/2020, 22:57:01
# 988    NaN  02/14/2020, 22:57:01   /img/kitten1   02/14/2020, 22:57:01
# 989    NaN  02/14/2020, 22:57:01   /img/kitten2   02/14/2020, 22:57:01
# 990    NaN  02/14/2020, 22:57:01   /img/kitten3   02/14/2020, 22:57:01
# 991    NaN  02/14/2020, 22:57:01   /img/kitten1   02/14/2020, 22:57:01
# 992    NaN  02/14/2020, 22:57:01   /img/kitten2   02/14/2020, 22:57:01
# 993    NaN  02/14/2020, 22:57:01   /img/kitten3   02/14/2020, 22:57:01
#
# [994 rows x 16 columns]

# %%
import pandas as pd
import ast
import json
import requests
import xmltodict
from pandas.io.json import json_normalize #package for flattening json in pandas df


pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', 40)


df2 = pd.DataFrame()


itemz = []

with open('app.log') as f:
   items = f.read().split("**********************************************")[1:]
   print (len(items))
   i = 0 
   for s in items:
          i+=1 
          if (i%1000 ==0 ):
             print("i " + str(i))
             df = pd.DataFrame(itemz)
             df.to_csv('DF32.csv')
          item = {}
          lines = s.splitlines()
          if ("Forwarded:" in s):
              item['path'] = lines[1]
              item['time'] = lines[3].lstrip('time: ')
              #item['Referer'] = lines[5].lstrip('Referer: ')
              item['User-Agent'] = lines[6].lstrip('User-Agent: ')
              item['Connection'] = lines[7].lstrip('Connection: ')
              item['cookie'] = lines[2].lstrip("MMM COOKIE ").rstrip("@@@")
              #item['Host'] = lines[9].lstrip('Host: ' )
              #item['Upgrade-Insecure-Requests'] = lines[10].strip('Upgrade-Insecure-Requests: ')
              item['Accept']          = lines[10].lstrip('Accept: ')
              item['Accept-Language'] = lines[11].lstrip('Accept-Language: ')
              item['Accept-Encoding'] = lines[12].lstrip('Accept-Encoding: ')
              url = "https://freegeoip.app/xml/"
              ip = lines[8].lstrip('Forwarded: for="').rstrip('"')
              ipp = [itm for itm in itemz if itm["IP"] == ip]
              
               
              if bool(ipp):
                  ipp = ipp[0]
                  item['IP'] = ip 
                  item['CountryCode'] = ipp['CountryCode']
                  item['RegionCode'] = ipp['RegionCode']
                  item['City'] = ipp['City']
                  item['ZipCode'] = ipp['ZipCode']
              else:  
                  response = requests.get(url+ip)
                  try:
                    response = xmltodict.parse(response.text)['Response']
                  except:
                    print("error parsing XML dict!")
                    print(s + " @@@\n")
                    print(response.text + " @@@\n")
                    print(ip + " @@@\n")
                    continue
                  
                  item['IP'] = ip
                  item['CountryCode'] = response['CountryCode']
                  item['RegionCode'] = response['RegionCode']
                  item['City'] = response['City']
                  item['ZipCode'] = response['ZipCode']
              itemz.append(item)

df = pd.DataFrame(itemz)
#df

df.to_csv('DF2.csv', index=False) 

df3 = pd.read_csv("DF2.csv")
df3

# %%
import pandas as pd
import ast
import json
import requests
import xmltodict
from pandas.io.json import json_normalize #package for flattening json in pandas df


pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', 40)


df2 = pd.DataFrame()

def find_str(l, subs):
    for i, s in enumerate(l):
        if subs in s:
              return s
    return ""
itemz = []

with open('app.log') as f:
   items = f.read().split("**********************************************")[1:]
   print (len(items))
   i = 0 
   for s in items[:100]:
          i+=1 
          if (i%1000 ==0 ):
             print("i " + str(i))
             df = pd.DataFrame(itemz)
             df.to_csv('DF32.csv')
          item = {}
          lines = s.splitlines()
          if ("Forwarded:" in s):
              item['path'] = find_str(lines, "/img/").lstrip("/img/")
              item['date'] = find_str(lines, "time").rstrip(',')
              item['time'] = find_str(lines, "time").lstrip(',')
              #item['Referer'] = lines[5].lstrip('Referer: ')
              item['User-Agent'] = find_str(lines, "User-Agent").lstrip('User-Agent: ')
              item['Connection'] = find_str(lines, "Connection").lstrip('Connection: ')
              item['cookie'] = find_str(lines, "MMM COOKIE").lstrip("MMM COOKIE ").rstrip("@@@")
              #item['Host'] = lines[9].lstrip('Host: ' )
              #item['Upgrade-Insecure-Requests'] = lines[10].strip('Upgrade-Insecure-Requests: ')
              item['Accept']          = find_str(lines, "Accept:").lstrip('Accept: ')
              item['Accept-Language'] = find_str(lines, "Accept-Language:").lstrip('Accept-Language: ')
              item['Accept-Encoding'] = find_str(lines, "Accept-Encoding:").lstrip('Accept-Encoding: ')
              url = "https://freegeoip.app/xml/"
              ip = find_str(lines, "Forwarded: for=").lstrip('Forwarded: for="').rstrip('"')
              ipp = [itm for itm in itemz if itm["IP"] == ip]
#               if bool(ipp):
#                   ipp = ipp[0]
#                   item['IP'] = ip 
#                   item['CountryCode'] = ipp['CountryCode']
#                   item['RegionCode'] = ipp['RegionCode']
#                   item['City'] = ipp['City']
#                   item['ZipCode'] = ipp['ZipCode']
#               else:  
#                   response = requests.get(url+ip)
#                   try:
#                     response = xmltodict.parse(response.text)['Response']
#                   except:
#                     print("error parsing XML dict!")
#                     print(s + " @@@\n")
#                     print(response.text + " @@@\n")
#                     print(ip + " @@@\n")
#                     continue

#                   item['IP'] = ip
#                   item['CountryCode'] = response['CountryCode']
#                   item['RegionCode'] = response['RegionCode']
#                   item['City'] = response['City']
#                   item['ZipCode'] = response['ZipCode']
              itemz.append(item)


df = pd.DataFrame(itemz)
df.to_csv('DF2.csv') 


df
