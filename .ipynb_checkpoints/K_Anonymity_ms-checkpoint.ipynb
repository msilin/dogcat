# %%
import pandas as pd
import matplotlib.pyplot as plt

#df = pd.read_csv("localtime.csv", index_col=[0])
df = pd.read_csv("localtime.csv", )


df = df.drop(['Accept','date', 'Connection','Accept-Encoding', 'Accept-Language','CountryName','City'], 1)
df
# Out:
#        CountryCode               IP  \
# 0               KR  222.239.168.135
# 1               KR  222.239.168.135
# 2               KR  222.239.168.135
# 3               KR  222.239.168.135
# 4               KR  222.239.168.135
# 5               KR  222.239.168.135
# 6               KR  222.239.168.135
# 7               US    23.90.192.153
# 8               US    23.90.192.153
# 9               US    23.90.192.153
# 10              US    23.90.192.153
# 11              US    23.90.192.153
# 12              US    23.90.192.153
# 13              US    23.90.192.153
# 14              US    23.90.192.153
# 15              US    23.90.192.153
# 16              US    24.112.128.30
# 17              US    24.112.128.30
# 18              US    24.112.128.30
# 19              US    24.112.128.30
# 20              US    24.112.128.30
# 21              US    24.112.128.30
# 22              US   130.45.245.242
# 23              US   130.45.245.242
# 24              US   130.45.245.242
# ...

# %%
df.groupby(["IP","cookie","path"]).size().to_frame()
# Out:
#                                                  0
# IP              cookie                path
# 101.242.160.152 02/14/2020, 22:55:33  puppy2     1
#                                       puppy3     3
#                 02/14/2020, 22:55:34  kitten1    2
#                                       puppy3     2
#                 02/14/2020, 22:56:59  kitten2    1
#                                       kitten3    1
#                                       puppy3     1
#                 02/14/2020, 22:57:00  kitten1    1
#                                       kitten2    3
#                                       kitten3    1
#                                       puppy1     1
#                                       puppy2     1
#                 02/14/2020, 23:21:16  kitten2    1
#                                       kitten3    1
#                                       puppy1     2
#                                       puppy2     1
#                                       puppy3     1
# ...

# %%
import pycountry_convert as pc

def country_to_cont(cc):
    cont_code = pc.country_alpha2_to_continent_code(cc)
    cont_name = pc.convert_continent_code_to_continent_name(cont_code)
    return cont_name

# %%
df_t = df.loc[df['CountryCode'].notna()].copy(deep=True)
df_t['Continent'] = df_t.apply(lambda row: country_to_cont(row['CountryCode']), axis=1)
df_t = df_t.drop(['CountryCode'],1)
df_t['localtime']=df_t['localtime'].str[:3]

# %%
df_t = df_t.groupby(["Continent","User-Agent","localtime"]).size().sort_values(ascending=False).reset_index(name="Count")
df_t
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-83-6830f9aa83ed> in <module>
#       1
# ----> 2 df_t = df_t.groupby(["Continent","User-Agent","localtime"]).size().sort_values(ascending=False).reset_index(name="Count")
#       3 df_t
#
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    6663         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    6664                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 6665                        observed=observed, **kwargs)
#    6666
#    6667     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# /usr/local/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in groupby(obj, by, **kwds)
# ...
