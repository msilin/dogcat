# %%
import pandas as pd

df = pd.read_csv("DF.csv")
df = df.drop['Accept']
df
#Countries = df.groupby(['CountryCode']).size().sort_values(ascending=False)
#Countries.reset_index()
# Out:
#       Accept Accept-Encoding Accept-Language         City  Connection  \
# 0        */*             zip              sw        Busan  keep-alive
# 1        */*             zip              sw        Busan  keep-alive
# 2        */*             zip              sw        Busan  keep-alive
# 3        */*             zip              sw        Busan  keep-alive
# 4        */*             zip              sw        Busan  keep-alive
# 5        */*             zip              sw        Busan  keep-alive
# 6        */*             zip              sw        Busan  keep-alive
# 7        */*             zip              oj          NaN  keep-alive
# 8        */*             zip              oj          NaN  keep-alive
# 9        */*             zip              oj          NaN  keep-alive
# 10       */*             zip              oj          NaN  keep-alive
# 11       */*             zip              oj          NaN  keep-alive
# 12       */*             zip              oj          NaN  keep-alive
# 13       */*             zip              oj          NaN  keep-alive
# 14       */*             zip              oj          NaN  keep-alive
# 15       */*             zip              oj          NaN  keep-alive
# 16       */*             zip               s  Forest Hill  keep-alive
# 17       */*             zip               s  Forest Hill  keep-alive
# 18       */*             zip               s  Forest Hill  keep-alive
# 19       */*             zip               s  Forest Hill  keep-alive
# 20       */*             zip               s  Forest Hill  keep-alive
# 21       */*             zip               s  Forest Hill  keep-alive
# 22       */*             zip              fr          NaN  keep-alive
# 23       */*             zip              fr          NaN  keep-alive
# 24       */*             zip              fr          NaN  keep-alive
# 25       */*             zip              fr          NaN  keep-alive
# 26       */*             zip              fr          NaN  keep-alive
# 27       */*             zip              fr          NaN  keep-alive
# 28       */*             zip             NaN      Beijing  keep-alive
# 29       */*             zip             NaN      Beijing  keep-alive
# ...      ...             ...             ...          ...         ...
# 95901    */*             zip              lg          NaN  keep-alive
# 95902    */*             zip              lg          NaN  keep-alive
# 95903    */*             zip              lg          NaN  keep-alive
# 95904    */*             zip              lg          NaN  keep-alive
# 95905    */*             zip              lg          NaN  keep-alive
# 95906    */*             zip              lg          NaN  keep-alive
# 95907    */*             zip             NaN     Honolulu  keep-alive
# 95908    */*             zip             NaN     Honolulu  keep-alive
# 95909    */*             zip             NaN     Honolulu  keep-alive
# 95910    */*             zip             NaN     Honolulu  keep-alive
# 95911    */*             zip             NaN     Honolulu  keep-alive
# 95912    */*             zip             NaN     Honolulu  keep-alive
# 95913    */*             zip             NaN     Honolulu  keep-alive
# 95914    */*             zip             NaN     Honolulu  keep-alive
# 95915    */*             zip             NaN     Honolulu  keep-alive
# 95916    */*             zip             NaN     Honolulu  keep-alive
# 95917    */*             zip             NaN     Honolulu  keep-alive
# 95918    */*             zip             NaN     Honolulu  keep-alive
# 95919    */*             zip             NaN     Honolulu  keep-alive
# 95920    */*             zip             NaN     Honolulu  keep-alive
# 95921    */*             zip             NaN     Honolulu  keep-alive
# 95922    */*             zip             NaN     Honolulu  keep-alive
# 95923    */*             zip             NaN     Honolulu  keep-alive
# 95924    */*             zip             NaN     Honolulu  keep-alive
# 95925    */*             zip             NaN     Honolulu  keep-alive
# 95926    */*             zip             NaN     Honolulu  keep-alive
# 95927    */*             zip             NaN     Honolulu  keep-alive
# 95928    */*             zip             NaN     Honolulu  keep-alive
# 95929    */*             zip             NaN     Honolulu  keep-alive
# 95930    */*             zip             NaN     Honolulu  keep-alive
#
#       CountryCode               IP RegionCode  \
# 0              KR  222.239.168.135         26
# 1              KR  222.239.168.135         26
# 2              KR  222.239.168.135         26
# 3              KR  222.239.168.135         26
# 4              KR  222.239.168.135         26
# 5              KR  222.239.168.135         26
# 6              KR  222.239.168.135         26
# 7              US    23.90.192.153        NaN
# 8              US    23.90.192.153        NaN
# 9              US    23.90.192.153        NaN
# 10             US    23.90.192.153        NaN
# 11             US    23.90.192.153        NaN
# 12             US    23.90.192.153        NaN
# 13             US    23.90.192.153        NaN
# 14             US    23.90.192.153        NaN
# 15             US    23.90.192.153        NaN
# 16             US    24.112.128.30         MD
# 17             US    24.112.128.30         MD
# 18             US    24.112.128.30         MD
# 19             US    24.112.128.30         MD
# 20             US    24.112.128.30         MD
# 21             US    24.112.128.30         MD
# 22             US   130.45.245.242        NaN
# 23             US   130.45.245.242        NaN
# 24             US   130.45.245.242        NaN
# 25             US   130.45.245.242        NaN
# 26             US   130.45.245.242        NaN
# 27             US   130.45.245.242        NaN
# 28             CN   114.242.145.68         BJ
# 29             CN   114.242.145.68         BJ
# ...           ...              ...        ...
# 95901         NaN    253.96.38.243        NaN
# 95902         NaN    253.96.38.243        NaN
# 95903         NaN    253.96.38.243        NaN
# 95904         NaN    253.96.38.243        NaN
# 95905         NaN    253.96.38.243        NaN
# 95906         NaN    253.96.38.243        NaN
# 95907          US   141.239.244.95         HI
# 95908          US   141.239.244.95         HI
# 95909          US   141.239.244.95         HI
# 95910          US   141.239.244.95         HI
# 95911          US   141.239.244.95         HI
# 95912          US   141.239.244.95         HI
# 95913          US   141.239.244.95         HI
# 95914          US   141.239.244.95         HI
# 95915          US   141.239.244.95         HI
# 95916          US   141.239.244.95         HI
# 95917          US   141.239.244.95         HI
# 95918          US   141.239.244.95         HI
# 95919          US   141.239.244.95         HI
# 95920          US   141.239.244.95         HI
# 95921          US   141.239.244.95         HI
# 95922          US   141.239.244.95         HI
# 95923          US   141.239.244.95         HI
# 95924          US   141.239.244.95         HI
# 95925          US   141.239.244.95         HI
# 95926          US   141.239.244.95         HI
# 95927          US   141.239.244.95         HI
# 95928          US   141.239.244.95         HI
# 95929          US   141.239.244.95         HI
# 95930          US   141.239.244.95         HI
#
#                                               User-Agent ZipCode  \
# 0      Mozilla/5.0 (Windows NT 10.0; Win64; x64; Xbox...   48943
# 1      Mozilla/5.0 (Windows NT 10.0; Win64; x64; Xbox...   48943
# 2      Mozilla/5.0 (Windows NT 10.0; Win64; x64; Xbox...   48943
# 3      Mozilla/5.0 (Windows NT 10.0; Win64; x64; Xbox...   48943
# 4      Mozilla/5.0 (Windows NT 10.0; Win64; x64; Xbox...   48943
# 5      Mozilla/5.0 (Windows NT 10.0; Win64; x64; Xbox...   48943
# 6      Mozilla/5.0 (Windows NT 10.0; Win64; x64; Xbox...   48943
# 7      Mozilla/5.0 (Macintosh; Intel Mac OS X 10.12; ...     NaN
# 8      Mozilla/5.0 (Macintosh; Intel Mac OS X 10.12; ...     NaN
# 9      Mozilla/5.0 (Macintosh; Intel Mac OS X 10.12; ...     NaN
# 10     Mozilla/5.0 (Macintosh; Intel Mac OS X 10.12; ...     NaN
# 11     Mozilla/5.0 (Macintosh; Intel Mac OS X 10.12; ...     NaN
# 12     Mozilla/5.0 (Macintosh; Intel Mac OS X 10.12; ...     NaN
# 13     Mozilla/5.0 (Macintosh; Intel Mac OS X 10.12; ...     NaN
# 14     Mozilla/5.0 (Macintosh; Intel Mac OS X 10.12; ...     NaN
# 15     Mozilla/5.0 (Macintosh; Intel Mac OS X 10.12; ...     NaN
# 16        Mozilla/2.0 (compatible; MSIE 4.0; Windows 98)   21050
# 17        Mozilla/2.0 (compatible; MSIE 4.0; Windows 98)   21050
# 18        Mozilla/2.0 (compatible; MSIE 4.0; Windows 98)   21050
# 19        Mozilla/2.0 (compatible; MSIE 4.0; Windows 98)   21050
# 20        Mozilla/2.0 (compatible; MSIE 4.0; Windows 98)   21050
# 21        Mozilla/2.0 (compatible; MSIE 4.0; Windows 98)   21050
# 22     Mozilla/5.0 (GNU; rv:1.9.1.7) Gecko/20100107 I...     NaN
# 23     Mozilla/5.0 (GNU; rv:1.9.1.7) Gecko/20100107 I...     NaN
# 24     Mozilla/5.0 (GNU; rv:1.9.1.7) Gecko/20100107 I...     NaN
# 25     Mozilla/5.0 (GNU; rv:1.9.1.7) Gecko/20100107 I...     NaN
# 26     Mozilla/5.0 (GNU; rv:1.9.1.7) Gecko/20100107 I...     NaN
# 27     Mozilla/5.0 (GNU; rv:1.9.1.7) Gecko/20100107 I...     NaN
# 28        Mozilla/2.0 (compatible; MSIE 4.0; Windows 98)     NaN
# 29        Mozilla/2.0 (compatible; MSIE 4.0; Windows 98
02/19/2020, 22:36:03   02/19/2020  kitten2   22:37:24
# 95914  02/19/2020, 22:36:03   02/19/2020  kitten2   22:37:24
# 95915  02/19/2020, 22:37:18   02/19/2020  kitten3   22:37:24
# 95916  02/19/2020, 22:36:03   02/19/2020  kitten1   22:37:26
# 95917  02/19/2020, 22:36:03   02/19/2020  kitten1   22:37:26
# 95918  02/19/2020, 22:37:18   02/19/2020  kitten1   22:37:27
# 95919  02/19/2020, 22:36:03   02/19/2020  kitten2   22:37:29
# 95920  02/19/2020, 22:36:03   02/19/2020  kitten2   22:37:29
# 95921  02/19/2020, 22:37:18   02/19/2020  kitten2   22:37:29
# 95922  02/19/2020, 22:36:03   02/19/2020  kitten1   22:37:32
# 95923  02/19/2020, 22:36:03   02/19/2020  kitten1   22:37:32
# 95924  02/19/2020, 22:37:18   02/19/2020  kitten3   22:37:32
# 95925  02/19/2020, 22:36:03   02/19/2020  kitten3   22:37:35
# 95926  02/19/2020, 22:36:03   02/19/2020  kitten3   22:37:35
# 95927  02/19/2020, 22:37:18   02/19/2020  kitten1   22:37:35
# 95928  02/19/2020, 22:36:03   02/19/2020  kitten2   22:37:38
# 95929  02/19/2020, 22:36:03   02/19/2020  kitten2   22:37:38
# 95930  02/19/2020, 22:37:18   02/19/2020  kitten1   22:37:38
#
# [95931 rows x 14 columns]

# %%
#Countries.plot.bar(figsize=(30,20),fontsize=18)

# %%
Animals = df.groupby(['path']).size().sort_values(ascending=False)

# %%
#Animals.plot.bar(figsize=(25,25),fontsize=18)

# %%
df2 = df
df2['time'] = df['time'].str[:3]
df2
Times = df.groupby(['time']).size().sort_values(ascending=False)
Times
Times.plot.bar(figsize=(25,25),fontsize=18)

# %%
df3 = df


Preferences = df.groupby(['IP','path']).size()
Preferences 
#data.groupby(['col1', 'col2'])
#Times.plot.bar(figsize=(25,25),fontsize=18)
# Out:
# IP               path
# 101.242.160.152  kitten1     37
#                  kitten2     46
#                  kitten3     49
#                  puppy1      62
#                  puppy2      66
#                  puppy3      58
# 102.138.212.174  kitten1     26
#                  kitten2     37
#                  kitten3     30
#                  puppy1      28
#                  puppy2      29
#                  puppy3      27
# 102.149.55.242   kitten1     28
#                  kitten2     30
#                  kitten3     41
#                  puppy1      28
#                  puppy2      33
#                  puppy3      34
# 104.219.14.14    kitten1     61
#                  kitten2     58
#                  kitten3     45
#                  puppy1      56
#                  puppy2      46
#                  puppy3      44
# 104.90.22.63     kitten1     53
#                  kitten2     36
#                  kitten3     38
#                  puppy1      40
#                  puppy2      34
#                  puppy3      43
#                            ...
# 93.195.61.73     kitten1     51
#                  kitten2     63
#                  kitten3     45
# 94.200.108.162   kitten1     31
#                  kitten2     27
#                  kitten3     30
#                  puppy1      38
#                  puppy2      28
#                  puppy3      43
# 94.37.248.204    kitten1     90
#                  kitten2     80
#                  kitten3     61
#                  puppy1      68
#                  puppy2      70
#                  puppy3      73
# 95.92.24.145     kitten1    112
#                  kitten2     76
#                  kitten3     87
#                  puppy1      72
#                  puppy2     107
#                  puppy3      99
# 96.22.23.175     kitten1     89
#                  kitten2     94
#                  kitten3     82
# 98.26.248.237    kitten1     49
#                  kitten2     44
#                  kitten3     45
#                  puppy1      50
#                  puppy2      53
#                  puppy3      41
# Length: 1488, dtype: int64
